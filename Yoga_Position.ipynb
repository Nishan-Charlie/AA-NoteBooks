# %% [markdown]
# <a href="https://colab.research.google.com/github/Nishan-Charlie/AA-NoteBooks/blob/main/Yoga_Position.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import cv2
import numpy as np
import torch
import math
import os

# Clone the ultralytics repository
# !git clone https://github.com/ultralytics/ultralytics.git
# %cd ultralytics
# !pip install -e .

# Load YOLOv8 pose model from local repository
# model = torch.hub.load('ultralytics/ultralytics', 'yolov8s-pose', pretrained=True)
from ultralytics import YOLO
model = YOLO('yolov8s-pose.pt')


# Video path
video_path = "/content/drive/MyDrive/Research/10 min Yoga for Beginners - Gentle & Simple Yoga Stretch.mp4"
output_video_path = "output_yoga_pose.mp4"

# Function to calculate angle between three points
def calculate_angle(p1, p2, p3):
    if p1 is None or p2 is None or p3 is None:
        return 0
    # Convert to numpy arrays if not already
    p1 = np.array(p1)
    p2 = np.array(p2)
    p3 = np.array(p3)

    # Vectors
    v1 = p1 - p2
    v2 = p3 - p2

    # Dot product
    dot = np.dot(v1, v2)

    # Magnitudes
    mag1 = np.linalg.norm(v1)
    mag2 = np.linalg.norm(v2)

    if mag1 == 0 or mag2 == 0:
        return 0

    # Cosine of angle
    cos = dot / (mag1 * mag2)
    cos = np.clip(cos, -1.0, 1.0)

    # Angle in degrees
    angle = math.degrees(math.acos(cos))
    return angle

# Skeleton connections for COCO keypoints
connections = [
    (5, 7), (7, 9), (6, 8), (8, 10),  # Arms
    (11, 13), (13, 15), (12, 14), (14, 16),  # Legs
    (5, 6), (5, 11), (6, 12), (11, 12),  # Torso
    (0, 1), (0, 2), (1, 3), (2, 4), (0, 5), (0, 6)  # Head
]

# Function to process frame
def process_frame(frame):
    # Convert to RGB
    rgb_frame = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)
    # Detect poses
    results = model(rgb_frame)
    # Get detections
    if hasattr(results[0], 'keypoints'):
        keypoints_list = results[0].keypoints.xy.cpu().numpy()  # (num_persons, 17, 2)
        boxes = results[0].boxes.xyxy.cpu().numpy()
        confs = results[0].boxes.conf.cpu().numpy()
    else:
        return frame  # No detection

    for idx, (kpts, box, conf) in enumerate(zip(keypoints_list, boxes, confs)):
        if conf < 0.5:
            continue
        # Draw bounding box
        x1, y1, x2, y2 = map(int, box)
        cv2.rectangle(frame, (x1, y1), (x2, y2), (0, 255, 0), 2)

        # Draw skeleton
        for conn in connections:
            pt1 = (int(kpts[conn[0]][0]), int(kpts[conn[0]][1])) if kpts[conn[0]][0] > 0 else None
            pt2 = (int(kpts[conn[1]][0]), int(kpts[conn[1]][1])) if kpts[conn[1]][0] > 0 else None
            if pt1 and pt2:
                # Check if keypoints are within the frame boundaries before drawing
                if 0 <= pt1[0] < frame.shape[1] and 0 <= pt1[1] < frame.shape[0] and \
                   0 <= pt2[0] < frame.shape[1] and 0 <= pt2[1] < frame.shape[0]:
                    cv2.line(frame, pt1, pt2, (255, 0, 0), 2)


        # Calculate and overlay angles
        # Left elbow angle: shoulder(5)-elbow(7)-wrist(9)
        left_elbow_angle = calculate_angle(kpts[5], kpts[7], kpts[9])
        cv2.putText(frame, f"L Elbow: {left_elbow_angle:.1f}", (x1, y1 - 60), cv2.FONT_HERSHEY_SIMPLEX, 0.5, (0, 0, 255), 2)

        # Right elbow angle: shoulder(6)-elbow(8)-wrist(10)
        right_elbow_angle = calculate_angle(kpts[6], kpts[8], kpts[10])
        cv2.putText(frame, f"R Elbow: {right_elbow_angle:.1f}", (x1, y1 - 45), cv2.FONT_HERSHEY_SIMPLEX, 0.5, (0, 0, 255), 2)

        # Left knee angle: hip(11)-knee(13)-ankle(15)
        left_knee_angle = calculate_angle(kpts[11], kpts[13], kpts[15])
        cv2.putText(frame, f"L Knee: {left_knee_angle:.1f}", (x1, y1 - 30), cv2.FONT_HERSHEY_SIMPLEX, 0.5, (0, 0, 255), 2)

        # Right knee angle: hip(12)-knee(14)-ankle(16)
        right_knee_angle = calculate_angle(kpts[12], kpts[14], kpts[16])
        cv2.putText(frame, f"R Knee: {right_knee_angle:.1f}", (x1, y1 - 15), cv2.FONT_HERSHEY_SIMPLEX, 0.5, (0, 0, 255), 2)

        # Left hip angle: shoulder(5)-hip(11)-knee(13)
        left_hip_angle = calculate_angle(kpts[5], kpts[11], kpts[13])
        cv2.putText(frame, f"L Hip: {left_hip_angle:.1f}", (x1 + 150, y1 - 60), cv2.FONT_HERSHEY_SIMPLEX, 0.5, (0, 0, 255), 2)

        # Right hip angle: shoulder(6)-hip(12)-knee(14)
        right_hip_angle = calculate_angle(kpts[6], kpts[12], kpts[14])
        cv2.putText(frame, f"R Hip: {right_hip_angle:.1f}", (x1 + 150, y1 - 45), cv2.FONT_HERSHEY_SIMPLEX, 0.5, (0, 0, 255), 2)


    return frame

# Main function for video processing
def main():
    cap = cv2.VideoCapture(video_path)
    if not cap.isOpened():
        print("Error opening video file")
        return

    # Get video properties
    fps = cap.get(cv2.CAP_PROP_FPS)
    width = int(cap.get(cv2.CAP_PROP_FRAME_WIDTH))
    height = int(cap.get(cv2.CAP_PROP_FRAME_HEIGHT))

    # Output video writer
    fourcc = cv2.VideoWriter_fourcc(*'mp4v')
    out = cv2.VideoWriter(output_video_path, fourcc, fps, (width, height))

    frame_count = 0
    while cap.isOpened():
        ret, frame = cap.read()
        if not ret:
            break

        # Process frame
        processed_frame = process_frame(frame)

        # Write to output
        out.write(processed_frame)

        frame_count += 1
        if frame_count % 100 == 0:
            print(f"Processed {frame_count} frames")

    cap.release()
    out.release()
    print("Output video saved to", output_video_path)

if __name__ == "__main__":
    main()
# Out:
# Streaming output truncated to the last 5000 lines.
# 0: 384x640 1 person, 409.7ms
# Speed: 4.0ms preprocess, 409.7ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 396.0ms
# Speed: 4.1ms preprocess, 396.0ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 402.4ms
# Speed: 4.1ms preprocess, 402.4ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 398.8ms
# Speed: 4.8ms preprocess, 398.8ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 395.1ms
# Speed: 4.2ms preprocess, 395.1ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 409.3ms
# Speed: 4.7ms preprocess, 409.3ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 394.4ms
# Speed: 4.1ms preprocess, 394.4ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 409.8ms
# Speed: 4.3ms preprocess, 409.8ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 396.5ms
# Speed: 3.0ms preprocess, 396.5ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 410.6ms
# Speed: 2.7ms preprocess, 410.6ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 409.9ms
# Speed: 4.5ms preprocess, 409.9ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 398.2ms
# Speed: 4.8ms preprocess, 398.2ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 411.4ms
# Speed: 6.0ms preprocess, 411.4ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 396.4ms
# Speed: 4.2ms preprocess, 396.4ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 530.3ms
# Speed: 4.3ms preprocess, 530.3ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 619.4ms
# Speed: 4.9ms preprocess, 619.4ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 637.0ms
# Speed: 4.2ms preprocess, 637.0ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 627.9ms
# Speed: 4.3ms preprocess, 627.9ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 623.9ms
# Speed: 2.6ms preprocess, 623.9ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 641.0ms
# Speed: 2.6ms preprocess, 641.0ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
# Processed 18100 frames
#
# 0: 384x640 1 person, 617.2ms
# Speed: 2.7ms preprocess, 617.2ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 404.4ms
# Speed: 4.1ms preprocess, 404.4ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 395.6ms
# Speed: 2.9ms preprocess, 395.6ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 390.4ms
# Speed: 4.2ms preprocess, 390.4ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 403.3ms
# Speed: 6.4ms preprocess, 403.3ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 402.4ms
# Speed: 4.2ms preprocess, 402.4ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 433.7ms
# Speed: 4.1ms preprocess, 433.7ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 390.6ms
# Speed: 4.2ms preprocess, 390.6ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 403.9ms
# Speed: 4.0ms preprocess, 403.9ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 388.6ms
# Speed: 4.0ms preprocess, 388.6ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 400.0ms
# Speed: 4.2ms preprocess, 400.0ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 433.8ms
# Speed: 10.0ms preprocess, 433.8ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 399.5ms
# Speed: 4.2ms preprocess, 399.5ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 411.3ms
# Speed: 2.9ms preprocess, 411.3ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 392.3ms
# Speed: 5.0ms preprocess, 392.3ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 395.3ms
# Speed: 2.6ms preprocess, 395.3ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 406.5ms
# Speed: 4.2ms preprocess, 406.5ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 396.9ms
# Speed: 4.7ms preprocess, 396.9ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 409.8ms
# Speed: 4.2ms preprocess, 409.8ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 397.1ms
# Speed: 4.5ms preprocess, 397.1ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 390.7ms
# Speed: 4.6ms preprocess, 390.7ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 418.5ms
# Speed: 4.5ms preprocess, 418.5ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 418.0ms
# Speed: 4.1ms preprocess, 418.0ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 410.4ms
# Speed: 4.1ms preprocess, 410.4ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 619.3ms
# Speed: 4.2ms preprocess, 619.3ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 641.9ms
# Speed: 2.7ms preprocess, 641.9ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 620.2ms
# Speed: 2.6ms preprocess, 620.2ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 621.2ms
# Speed: 4.0ms preprocess, 621.2ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 618.8ms
# Speed: 2.6ms preprocess, 618.8ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 633.8ms
# Speed: 8.1ms preprocess, 633.8ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 507.3ms
# Speed: 4.5ms preprocess, 507.3ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 396.0ms
# Speed: 4.1ms preprocess, 396.0ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 408.6ms
# Speed: 2.8ms preprocess, 408.6ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 414.7ms
# Speed: 5.1ms preprocess, 414.7ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 410.5ms
# Speed: 2.7ms preprocess, 410.5ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 388.6ms
# Speed: 2.7ms preprocess, 388.6ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 394.7ms
# Speed: 4.5ms preprocess, 394.7ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 404.4ms
# Speed: 4.2ms preprocess, 404.4ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 386.5ms
# Speed: 4.0ms preprocess, 386.5ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 412.0ms
# Speed: 4.8ms preprocess, 412.0ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 394.9ms
# Speed: 4.0ms preprocess, 394.9ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 385.0ms
# Speed: 4.2ms preprocess, 385.0ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 412.6ms
# Speed: 3.0ms preprocess, 412.6ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 401.1ms
# Speed: 2.9ms preprocess, 401.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 419.2ms
# Speed: 4.5ms preprocess, 419.2ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 414.9ms
# Speed: 4.1ms preprocess, 414.9ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 394.4ms
# Speed: 5.7ms preprocess, 394.4ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 409.1ms
# Speed: 4.1ms preprocess, 409.1ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 395.8ms
# Speed: 4.2ms preprocess, 395.8ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 408.2ms
# Speed: 4.1ms preprocess, 408.2ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 392.7ms
# Speed: 4.4ms preprocess, 392.7ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 391.2ms
# Speed: 4.3ms preprocess, 391.2ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 396.4ms
# Speed: 7.7ms preprocess, 396.4ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 429.0ms
# Speed: 5.2ms preprocess, 429.0ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 633.4ms
# Speed: 4.1ms preprocess, 633.4ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 651.7ms
# Speed: 4.2ms preprocess, 651.7ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 613.5ms
# Speed: 2.6ms preprocess, 613.5ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 634.4ms
# Speed: 4.1ms preprocess, 634.4ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 621.9ms
# Speed: 4.2ms preprocess, 621.9ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 646.4ms
# Speed: 4.5ms preprocess, 646.4ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 464.4ms
# Speed: 4.1ms preprocess, 464.4ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 404.7ms
# Speed: 4.2ms preprocess, 404.7ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 390.8ms
# Speed: 4.9ms preprocess, 390.8ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 410.7ms
# Speed: 4.7ms preprocess, 410.7ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 393.2ms
# Speed: 5.3ms preprocess, 393.2ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 397.2ms
# Speed: 4.6ms preprocess, 397.2ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 396.0ms
# Speed: 2.6ms preprocess, 396.0ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 402.1ms
# Speed: 2.9ms preprocess, 402.1ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 408.1ms
# Speed: 4.8ms preprocess, 408.1ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 439.6ms
# Speed: 4.1ms preprocess, 439.6ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 406.6ms
# Speed: 4.8ms preprocess, 406.6ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 396.4ms
# Speed: 5.7ms preprocess, 396.4ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 392.1ms
# Speed: 5.1ms preprocess, 392.1ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 404.8ms
# Speed: 4.5ms preprocess, 404.8ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 401.9ms
# Speed: 2.5ms preprocess, 401.9ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 408.6ms
# Speed: 3.1ms preprocess, 408.6ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 397.9ms
# Speed: 2.6ms preprocess, 397.9ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 390.1ms
# Speed: 2.5ms preprocess, 390.1ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 412.6ms
# Speed: 2.8ms preprocess, 412.6ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 394.9ms
# Speed: 4.1ms preprocess, 394.9ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 404.7ms
# Speed: 4.0ms preprocess, 404.7ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 409.2ms
# Speed: 4.1ms preprocess, 409.2ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 404.4ms
# Speed: 4.6ms preprocess, 404.4ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 486.2ms
# Speed: 4.7ms preprocess, 486.2ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 645.1ms
# Speed: 4.2ms preprocess, 645.1ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 625.2ms
# Speed: 7.5ms preprocess, 625.2ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 666.7ms
# Speed: 2.6ms preprocess, 666.7ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 617.3ms
# Speed: 2.6ms preprocess, 617.3ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 637.9ms
# Speed: 6.2ms preprocess, 637.9ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 617.7ms
# Speed: 6.3ms preprocess, 617.7ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 393.7ms
# Speed: 2.7ms preprocess, 393.7ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 396.6ms
# Speed: 2.6ms preprocess, 396.6ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 406.2ms
# Speed: 6.2ms preprocess, 406.2ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 422.4ms
# Speed: 4.1ms preprocess, 422.4ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 410.3ms
# Speed: 4.2ms preprocess, 410.3ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 389.3ms
# Speed: 2.6ms preprocess, 389.3ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 412.2ms
# Speed: 4.0ms preprocess, 412.2ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 389.1ms
# Speed: 4.4ms preprocess, 389.1ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 396.6ms
# Speed: 2.8ms preprocess, 396.6ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 408.5ms
# Speed: 2.7ms preprocess, 408.5ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
# Processed 18200 frames
#
# 0: 384x640 1 person, 388.6ms
# Speed: 2.6ms preprocess, 388.6ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 406.0ms
# Speed: 4.1ms preprocess, 406.0ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 386.8ms
# Speed: 4.1ms preprocess, 386.8ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 406.1ms
# Speed: 2.6ms preprocess, 406.1ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 410.1ms
# Speed: 2.6ms preprocess, 410.1ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 408.8ms
# Speed: 4.3ms preprocess, 408.8ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 406.7ms
# Speed: 4.0ms preprocess, 406.7ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 396.8ms
# Speed: 5.2ms preprocess, 396.8ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 394.7ms
# Speed: 2.9ms preprocess, 394.7ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 404.2ms
# Speed: 2.6ms preprocess, 404.2ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 397.7ms
# Speed: 4.1ms preprocess, 397.7ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 408.8ms
# Speed: 3.8ms preprocess, 408.8ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 391.0ms
# Speed: 4.3ms preprocess, 391.0ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 571.5ms
# Speed: 4.2ms preprocess, 571.5ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 618.8ms
# Speed: 2.7ms preprocess, 618.8ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 640.2ms
# Speed: 4.1ms preprocess, 640.2ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 629.5ms
# Speed: 4.1ms preprocess, 629.5ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 638.9ms
# Speed: 4.1ms preprocess, 638.9ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 632.1ms
# Speed: 4.0ms preprocess, 632.1ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 546.0ms
# Speed: 6.8ms preprocess, 546.0ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 411.7ms
# Speed: 2.6ms preprocess, 411.7ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 397.8ms
# Speed: 4.5ms preprocess, 397.8ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 388.6ms
# Speed: 4.0ms preprocess, 388.6ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 413.0ms
# Speed: 4.1ms preprocess, 413.0ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 394.8ms
# Speed: 2.8ms preprocess, 394.8ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 418.8ms
# Speed: 4.1ms preprocess, 418.8ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 390.2ms
# Speed: 4.1ms preprocess, 390.2ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 392.6ms
# Speed: 4.7ms preprocess, 392.6ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 408.1ms
# Speed: 4.1ms preprocess, 408.1ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 410.1ms
# Speed: 2.7ms preprocess, 410.1ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 411.5ms
# Speed: 5.0ms preprocess, 411.5ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 400.0ms
# Speed: 4.5ms preprocess, 400.0ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 418.5ms
# Speed: 2.9ms preprocess, 418.5ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 412.8ms
# Speed: 4.8ms preprocess, 412.8ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 390.8ms
# Speed: 4.0ms preprocess, 390.8ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 409.6ms
# Speed: 4.3ms preprocess, 409.6ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 395.9ms
# Speed: 3.9ms preprocess, 395.9ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 413.8ms
# Speed: 2.9ms preprocess, 413.8ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 387.2ms
# Speed: 5.1ms preprocess, 387.2ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 386.4ms
# Speed: 2.9ms preprocess, 386.4ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 400.9ms
# Speed: 4.5ms preprocess, 400.9ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 410.5ms
# Speed: 4.1ms preprocess, 410.5ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 416.3ms
# Speed: 4.2ms preprocess, 416.3ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 610.1ms
# Speed: 2.7ms preprocess, 610.1ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 623.5ms
# Speed: 4.1ms preprocess, 623.5ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 626.8ms
# Speed: 4.0ms preprocess, 626.8ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 629.0ms
# Speed: 2.7ms preprocess, 629.0ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 616.2ms
# Speed: 2.6ms preprocess, 616.2ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 627.6ms
# Speed: 2.5ms preprocess, 627.6ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 502.6ms
# Speed: 2.7ms preprocess, 502.6ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 404.7ms
# Speed: 2.7ms preprocess, 404.7ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 412.3ms
# Speed: 2.6ms preprocess, 412.3ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 397.9ms
# Speed: 5.0ms preprocess, 397.9ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 411.1ms
# Speed: 3.8ms preprocess, 411.1ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 406.0ms
# Speed: 4.8ms preprocess, 406.0ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 393.2ms
# Speed: 5.0ms preprocess, 393.2ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 415.9ms
# Speed: 2.6ms preprocess, 415.9ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 396.0ms
# Speed: 2.7ms preprocess, 396.0ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 386.3ms
# Speed: 4.4ms preprocess, 386.3ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 409.6ms
# Speed: 5.2ms preprocess, 409.6ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 390.0ms
# Speed: 4.1ms preprocess, 390.0ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 401.5ms
# Speed: 4.3ms preprocess, 401.5ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 394.5ms
# Speed: 2.7ms preprocess, 394.5ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 394.5ms
# Speed: 2.7ms preprocess, 394.5ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 397.9ms
# Speed: 4.2ms preprocess, 397.9ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 403.5ms
# Speed: 5.4ms preprocess, 403.5ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 417.8ms
# Speed: 4.2ms preprocess, 417.8ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 389.7ms
# Speed: 2.6ms preprocess, 389.7ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 412.0ms
# Speed: 2.7ms preprocess, 412.0ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 400.0ms
# Speed: 4.4ms preprocess, 400.0ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 394.4ms
# Speed: 4.0ms preprocess, 394.4ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 407.7ms
# Speed: 4.5ms preprocess, 407.7ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 402.8ms
# Speed: 4.3ms preprocess, 402.8ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 628.1ms
# Speed: 4.3ms preprocess, 628.1ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 607.8ms
# Speed: 4.2ms preprocess, 607.8ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 634.0ms
# Speed: 4.6ms preprocess, 634.0ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 631.3ms
# Speed: 5.5ms preprocess, 631.3ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 721.4ms
# Speed: 4.1ms preprocess, 721.4ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 642.4ms
# Speed: 4.1ms preprocess, 642.4ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 496.1ms
# Speed: 4.3ms preprocess, 496.1ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 399.4ms
# Speed: 4.5ms preprocess, 399.4ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 392.9ms
# Speed: 6.0ms preprocess, 392.9ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 402.5ms
# Speed: 3.3ms preprocess, 402.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 383.0ms
# Speed: 4.2ms preprocess, 383.0ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 390.9ms
# Speed: 4.0ms preprocess, 390.9ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 403.8ms
# Speed: 4.4ms preprocess, 403.8ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 387.0ms
# Speed: 4.3ms preprocess, 387.0ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 411.9ms
# Speed: 3.1ms preprocess, 411.9ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 395.8ms
# Speed: 2.7ms preprocess, 395.8ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 429.8ms
# Speed: 4.3ms preprocess, 429.8ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 387.3ms
# Speed: 3.2ms preprocess, 387.3ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 392.8ms
# Speed: 4.2ms preprocess, 392.8ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 409.5ms
# Speed: 4.0ms preprocess, 409.5ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 394.4ms
# Speed: 4.7ms preprocess, 394.4ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 414.7ms
# Speed: 2.8ms preprocess, 414.7ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 390.4ms
# Speed: 5.8ms preprocess, 390.4ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 414.5ms
# Speed: 4.0ms preprocess, 414.5ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 413.5ms
# Speed: 2.6ms preprocess, 413.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 393.5ms
# Speed: 2.5ms preprocess, 393.5ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 406.5ms
# Speed: 4.4ms preprocess, 406.5ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
# Processed 18300 frames
#
# 0: 384x640 1 person, 401.4ms
# Speed: 4.8ms preprocess, 401.4ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 408.4ms
# Speed: 4.8ms preprocess, 408.4ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 435.4ms
# Speed: 2.5ms preprocess, 435.4ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 627.1ms
# Speed: 2.6ms preprocess, 627.1ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 604.7ms
# Speed: 4.2ms preprocess, 604.7ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 625.5ms
# Speed: 8.1ms preprocess, 625.5ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 625.5ms
# Speed: 2.5ms preprocess, 625.5ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 624.7ms
# Speed: 4.1ms preprocess, 624.7ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 630.6ms
# Speed: 4.0ms preprocess, 630.6ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 475.3ms
# Speed: 4.1ms preprocess, 475.3ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 382.6ms
# Speed: 4.2ms preprocess, 382.6ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 408.8ms
# Speed: 4.6ms preprocess, 408.8ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 388.2ms
# Speed: 4.0ms preprocess, 388.2ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 455.5ms
# Speed: 4.0ms preprocess, 455.5ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 393.6ms
# Speed: 4.1ms preprocess, 393.6ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 393.9ms
# Speed: 4.2ms preprocess, 393.9ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 423.3ms
# Speed: 2.6ms preprocess, 423.3ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 391.9ms
# Speed: 2.9ms preprocess, 391.9ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 408.0ms
# Speed: 2.9ms preprocess, 408.0ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 391.6ms
# Speed: 3.2ms preprocess, 391.6ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 406.5ms
# Speed: 5.1ms preprocess, 406.5ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 392.9ms
# Speed: 4.8ms preprocess, 392.9ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 390.8ms
# Speed: 2.5ms preprocess, 390.8ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 414.0ms
# Speed: 4.2ms preprocess, 414.0ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 386.8ms
# Speed: 4.0ms preprocess, 386.8ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 429.4ms
# Speed: 3.6ms preprocess, 429.4ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 388.5ms
# Speed: 4.5ms preprocess, 388.5ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 389.0ms
# Speed: 4.6ms preprocess, 389.0ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 415.4ms
# Speed: 4.3ms preprocess, 415.4ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 390.0ms
# Speed: 2.6ms preprocess, 390.0ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 407.0ms
# Speed: 4.0ms preprocess, 407.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 383.9ms
# Speed: 4.4ms preprocess, 383.9ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 444.5ms
# Speed: 4.7ms preprocess, 444.5ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 625.6ms
# Speed: 4.1ms preprocess, 625.6ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 625.7ms
# Speed: 4.0ms preprocess, 625.7ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 627.1ms
# Speed: 5.3ms preprocess, 627.1ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 631.9ms
# Speed: 4.3ms preprocess, 631.9ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 628.1ms
# Speed: 4.0ms preprocess, 628.1ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 629.2ms
# Speed: 4.2ms preprocess, 629.2ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 457.1ms
# Speed: 6.4ms preprocess, 457.1ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 394.7ms
# Speed: 4.1ms preprocess, 394.7ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 388.0ms
# Speed: 4.6ms preprocess, 388.0ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 405.9ms
# Speed: 2.6ms preprocess, 405.9ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 387.5ms
# Speed: 4.1ms preprocess, 387.5ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 404.9ms
# Speed: 3.9ms preprocess, 404.9ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 393.0ms
# Speed: 4.2ms preprocess, 393.0ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 389.5ms
# Speed: 4.2ms preprocess, 389.5ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 413.5ms
# Speed: 4.2ms preprocess, 413.5ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 398.2ms
# Speed: 3.7ms preprocess, 398.2ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 428.9ms
# Speed: 2.6ms preprocess, 428.9ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 395.4ms
# Speed: 4.4ms preprocess, 395.4ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 388.5ms
# Speed: 4.0ms preprocess, 388.5ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 413.3ms
# Speed: 3.2ms preprocess, 413.3ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 388.5ms
# Speed: 2.9ms preprocess, 388.5ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 401.2ms
# Speed: 2.7ms preprocess, 401.2ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 395.2ms
# Speed: 4.2ms preprocess, 395.2ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 394.6ms
# Speed: 4.1ms preprocess, 394.6ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 403.0ms
# Speed: 2.7ms preprocess, 403.0ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 399.4ms
# Speed: 4.2ms preprocess, 399.4ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 410.1ms
# Speed: 4.2ms preprocess, 410.1ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 411.9ms
# Speed: 5.2ms preprocess, 411.9ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 422.7ms
# Speed: 4.1ms preprocess, 422.7ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 468.4ms
# Speed: 4.0ms preprocess, 468.4ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 629.2ms
# Speed: 4.2ms preprocess, 629.2ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 602.0ms
# Speed: 4.1ms preprocess, 602.0ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 635.7ms
# Speed: 4.1ms preprocess, 635.7ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 613.9ms
# Speed: 2.8ms preprocess, 613.9ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 615.0ms
# Speed: 2.7ms preprocess, 615.0ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 641.4ms
# Speed: 4.1ms preprocess, 641.4ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 459.3ms
# Speed: 4.1ms preprocess, 459.3ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 391.7ms
# Speed: 4.2ms preprocess, 391.7ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 403.1ms
# Speed: 7.2ms preprocess, 403.1ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 388.5ms
# Speed: 4.0ms preprocess, 388.5ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 423.7ms
# Speed: 4.5ms preprocess, 423.7ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 393.5ms
# Speed: 4.0ms preprocess, 393.5ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 405.9ms
# Speed: 2.5ms preprocess, 405.9ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 394.1ms
# Speed: 2.7ms preprocess, 394.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 394.7ms
# Speed: 4.6ms preprocess, 394.7ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 400.9ms
# Speed: 4.0ms preprocess, 400.9ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 389.2ms
# Speed: 4.7ms preprocess, 389.2ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 406.9ms
# Speed: 4.0ms preprocess, 406.9ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 390.9ms
# Speed: 4.2ms preprocess, 390.9ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 387.1ms
# Speed: 3.3ms preprocess, 387.1ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 406.0ms
# Speed: 4.1ms preprocess, 406.0ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 395.2ms
# Speed: 5.5ms preprocess, 395.2ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 425.1ms
# Speed: 2.6ms preprocess, 425.1ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 401.2ms
# Speed: 2.6ms preprocess, 401.2ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 389.0ms
# Speed: 4.4ms preprocess, 389.0ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 409.4ms
# Speed: 3.0ms preprocess, 409.4ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 397.1ms
# Speed: 2.6ms preprocess, 397.1ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 409.3ms
# Speed: 2.8ms preprocess, 409.3ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 394.4ms
# Speed: 2.8ms preprocess, 394.4ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 418.0ms
# Speed: 2.5ms preprocess, 418.0ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 635.0ms
# Speed: 2.6ms preprocess, 635.0ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 626.8ms
# Speed: 4.1ms preprocess, 626.8ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 623.0ms
# Speed: 2.6ms preprocess, 623.0ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 626.3ms
# Speed: 2.7ms preprocess, 626.3ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 616.1ms
# Speed: 4.0ms preprocess, 616.1ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 634.5ms
# Speed: 4.0ms preprocess, 634.5ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 493.3ms
# Speed: 2.7ms preprocess, 493.3ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Processed 18400 frames
#
# 0: 384x640 1 person, 387.4ms
# Speed: 2.9ms preprocess, 387.4ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 388.6ms
# Speed: 2.6ms preprocess, 388.6ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 410.2ms
# Speed: 4.0ms preprocess, 410.2ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 389.5ms
# Speed: 2.7ms preprocess, 389.5ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 405.1ms
# Speed: 3.7ms preprocess, 405.1ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 389.5ms
# Speed: 4.4ms preprocess, 389.5ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 389.6ms
# Speed: 4.4ms preprocess, 389.6ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 413.7ms
# Speed: 4.2ms preprocess, 413.7ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 384.4ms
# Speed: 4.6ms preprocess, 384.4ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 423.4ms
# Speed: 4.3ms preprocess, 423.4ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 389.6ms
# Speed: 4.6ms preprocess, 389.6ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 397.1ms
# Speed: 4.1ms preprocess, 397.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 395.6ms
# Speed: 5.8ms preprocess, 395.6ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 389.4ms
# Speed: 2.6ms preprocess, 389.4ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 406.8ms
# Speed: 4.3ms preprocess, 406.8ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 390.3ms
# Speed: 4.1ms preprocess, 390.3ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 387.7ms
# Speed: 2.7ms preprocess, 387.7ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 407.6ms
# Speed: 4.1ms preprocess, 407.6ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 395.9ms
# Speed: 4.1ms preprocess, 395.9ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 399.2ms
# Speed: 4.3ms preprocess, 399.2ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 392.3ms
# Speed: 5.9ms preprocess, 392.3ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 431.5ms
# Speed: 4.8ms preprocess, 431.5ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 403.4ms
# Speed: 4.6ms preprocess, 403.4ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 632.5ms
# Speed: 2.7ms preprocess, 632.5ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 601.6ms
# Speed: 4.2ms preprocess, 601.6ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 626.3ms
# Speed: 4.0ms preprocess, 626.3ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 622.9ms
# Speed: 4.6ms preprocess, 622.9ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 609.8ms
# Speed: 2.7ms preprocess, 609.8ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 635.6ms
# Speed: 4.2ms preprocess, 635.6ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 487.5ms
# Speed: 4.1ms preprocess, 487.5ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 401.3ms
# Speed: 4.1ms preprocess, 401.3ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 391.5ms
# Speed: 3.2ms preprocess, 391.5ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 391.5ms
# Speed: 4.3ms preprocess, 391.5ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 419.6ms
# Speed: 4.6ms preprocess, 419.6ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 388.2ms
# Speed: 4.2ms preprocess, 388.2ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 407.1ms
# Speed: 4.8ms preprocess, 407.1ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 391.6ms
# Speed: 5.0ms preprocess, 391.6ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 398.8ms
# Speed: 4.4ms preprocess, 398.8ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 404.3ms
# Speed: 4.1ms preprocess, 404.3ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 388.5ms
# Speed: 2.7ms preprocess, 388.5ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 422.0ms
# Speed: 4.5ms preprocess, 422.0ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 399.8ms
# Speed: 4.2ms preprocess, 399.8ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 399.3ms
# Speed: 2.7ms preprocess, 399.3ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 405.3ms
# Speed: 5.1ms preprocess, 405.3ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 399.9ms
# Speed: 4.8ms preprocess, 399.9ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 435.8ms
# Speed: 3.0ms preprocess, 435.8ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 377.5ms
# Speed: 3.4ms preprocess, 377.5ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 397.2ms
# Speed: 3.2ms preprocess, 397.2ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 404.0ms
# Speed: 2.7ms preprocess, 404.0ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 384.6ms
# Speed: 4.0ms preprocess, 384.6ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 405.3ms
# Speed: 2.8ms preprocess, 405.3ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 388.7ms
# Speed: 4.1ms preprocess, 388.7ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 414.0ms
# Speed: 2.8ms preprocess, 414.0ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 617.4ms
# ...
#
# 0: 384x640 1 person, 626.8ms
# Speed: 2.8ms preprocess, 626.8ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 629.8ms
# Speed: 2.6ms preprocess, 629.8ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 416.8ms
# Speed: 4.1ms preprocess, 416.8ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 405.7ms
# Speed: 4.5ms preprocess, 405.7ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 391.2ms
# Speed: 2.8ms preprocess, 391.2ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 437.9ms
# Speed: 4.0ms preprocess, 437.9ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 392.2ms
# Speed: 2.6ms preprocess, 392.2ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 387.8ms
# Speed: 2.5ms preprocess, 387.8ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 402.7ms
# Speed: 3.0ms preprocess, 402.7ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 388.8ms
# Speed: 4.2ms preprocess, 388.8ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 414.0ms
# Speed: 4.0ms preprocess, 414.0ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 395.4ms
# Speed: 2.6ms preprocess, 395.4ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 390.9ms
# Speed: 4.1ms preprocess, 390.9ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 405.3ms
# Speed: 4.2ms preprocess, 405.3ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 384.9ms
# Speed: 4.1ms preprocess, 384.9ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 404.5ms
# Speed: 2.7ms preprocess, 404.5ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 396.5ms
# Speed: 4.2ms preprocess, 396.5ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 392.1ms
# Speed: 4.2ms preprocess, 392.1ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 405.6ms
# Speed: 5.3ms preprocess, 405.6ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 409.6ms
# Speed: 2.7ms preprocess, 409.6ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 412.7ms
# Speed: 4.2ms preprocess, 412.7ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 388.5ms
# Speed: 2.7ms preprocess, 388.5ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 392.6ms
# Speed: 4.3ms preprocess, 392.6ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 412.1ms
# Speed: 2.5ms preprocess, 412.1ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 389.6ms
# Speed: 4.7ms preprocess, 389.6ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 547.3ms
# Speed: 4.2ms preprocess, 547.3ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 632.2ms
# Speed: 4.1ms preprocess, 632.2ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 637.2ms
# Speed: 4.1ms preprocess, 637.2ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 638.4ms
# Speed: 5.2ms preprocess, 638.4ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 610.5ms
# Speed: 8.4ms preprocess, 610.5ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 633.4ms
# Speed: 2.6ms preprocess, 633.4ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 562.8ms
# Speed: 2.7ms preprocess, 562.8ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 407.5ms
# Speed: 2.4ms preprocess, 407.5ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 416.0ms
# Speed: 4.1ms preprocess, 416.0ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 418.5ms
# Speed: 4.9ms preprocess, 418.5ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 398.6ms
# Speed: 2.6ms preprocess, 398.6ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 392.9ms
# Speed: 2.7ms preprocess, 392.9ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 408.3ms
# Speed: 2.8ms preprocess, 408.3ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 389.4ms
# Speed: 2.5ms preprocess, 389.4ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 408.1ms
# Speed: 2.6ms preprocess, 408.1ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 394.0ms
# Speed: 4.3ms preprocess, 394.0ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 400.8ms
# Speed: 2.6ms preprocess, 400.8ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 390.1ms
# Speed: 4.1ms preprocess, 390.1ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 392.3ms
# Speed: 5.8ms preprocess, 392.3ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 419.3ms
# Speed: 2.5ms preprocess, 419.3ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 392.5ms
# Speed: 2.7ms preprocess, 392.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 410.5ms
# Speed: 4.1ms preprocess, 410.5ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 407.4ms
# Speed: 2.7ms preprocess, 407.4ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 386.7ms
# Speed: 3.9ms preprocess, 386.7ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 403.7ms
# Speed: 4.0ms preprocess, 403.7ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 391.2ms
# Speed: 4.9ms preprocess, 391.2ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 413.2ms
# Speed: 4.1ms preprocess, 413.2ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 395.2ms
# Speed: 2.8ms preprocess, 395.2ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 392.3ms
# Speed: 4.1ms preprocess, 392.3ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 411.3ms
# Speed: 4.0ms preprocess, 411.3ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 629.3ms
# Speed: 2.6ms preprocess, 629.3ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 632.6ms
# Speed: 2.5ms preprocess, 632.6ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 634.4ms
# Speed: 4.3ms preprocess, 634.4ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 622.4ms
# Speed: 2.5ms preprocess, 622.4ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 614.6ms
# Speed: 5.1ms preprocess, 614.6ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 629.0ms
# Speed: 4.1ms preprocess, 629.0ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 537.3ms
# Speed: 4.8ms preprocess, 537.3ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 396.4ms
# Speed: 4.1ms preprocess, 396.4ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 413.8ms
# Speed: 4.1ms preprocess, 413.8ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 391.2ms
# Speed: 4.4ms preprocess, 391.2ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 408.6ms
# Speed: 2.6ms preprocess, 408.6ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 407.2ms
# Speed: 2.8ms preprocess, 407.2ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 382.3ms
# Speed: 3.7ms preprocess, 382.3ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 409.1ms
# Speed: 4.1ms preprocess, 409.1ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 388.5ms
# Speed: 3.0ms preprocess, 388.5ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 396.3ms
# Speed: 3.0ms preprocess, 396.3ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 389.1ms
# Speed: 2.8ms preprocess, 389.1ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 390.7ms
# Speed: 2.5ms preprocess, 390.7ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 418.6ms
# Speed: 4.2ms preprocess, 418.6ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 393.6ms
# Speed: 3.7ms preprocess, 393.6ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 412.0ms
# Speed: 3.4ms preprocess, 412.0ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 419.7ms
# Speed: 2.6ms preprocess, 419.7ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 389.1ms
# Speed: 4.1ms preprocess, 389.1ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 401.5ms
# Speed: 6.0ms preprocess, 401.5ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 391.1ms
# Speed: 3.2ms preprocess, 391.1ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 404.4ms
# Speed: 2.6ms preprocess, 404.4ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 390.0ms
# Speed: 5.6ms preprocess, 390.0ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
# Processed 19700 frames
#
# 0: 384x640 1 person, 401.2ms
# Speed: 4.1ms preprocess, 401.2ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 401.5ms
# Speed: 4.1ms preprocess, 401.5ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 395.2ms
# Speed: 4.4ms preprocess, 395.2ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 627.4ms
# Speed: 2.7ms preprocess, 627.4ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 613.9ms
# Speed: 2.6ms preprocess, 613.9ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 618.9ms
# Speed: 4.2ms preprocess, 618.9ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 619.7ms
# Speed: 2.6ms preprocess, 619.7ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 638.7ms
# Speed: 7.2ms preprocess, 638.7ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 641.8ms
# Speed: 4.9ms preprocess, 641.8ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 510.9ms
# Speed: 4.2ms preprocess, 510.9ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 391.9ms
# Speed: 2.6ms preprocess, 391.9ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 389.0ms
# Speed: 4.3ms preprocess, 389.0ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 405.7ms
# Speed: 3.1ms preprocess, 405.7ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 389.7ms
# Speed: 4.3ms preprocess, 389.7ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 413.1ms
# Speed: 4.6ms preprocess, 413.1ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 390.6ms
# Speed: 3.0ms preprocess, 390.6ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 394.3ms
# Speed: 3.4ms preprocess, 394.3ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 411.1ms
# Speed: 4.2ms preprocess, 411.1ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 390.3ms
# Speed: 3.1ms preprocess, 390.3ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 433.2ms
# Speed: 4.2ms preprocess, 433.2ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 398.2ms
# Speed: 2.6ms preprocess, 398.2ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 396.7ms
# Speed: 4.5ms preprocess, 396.7ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 409.3ms
# Speed: 4.9ms preprocess, 409.3ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 396.0ms
# Speed: 2.8ms preprocess, 396.0ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 405.0ms
# Speed: 4.2ms preprocess, 405.0ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 393.6ms
# Speed: 4.7ms preprocess, 393.6ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 399.8ms
# Speed: 5.0ms preprocess, 399.8ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 392.7ms
# Speed: 4.3ms preprocess, 392.7ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 401.9ms
# Speed: 2.6ms preprocess, 401.9ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 406.9ms
# Speed: 2.8ms preprocess, 406.9ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 391.6ms
# Speed: 2.6ms preprocess, 391.6ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 409.5ms
# Speed: 2.9ms preprocess, 409.5ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 479.2ms
# Speed: 4.0ms preprocess, 479.2ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 631.5ms
# Speed: 4.1ms preprocess, 631.5ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 607.1ms
# Speed: 4.0ms preprocess, 607.1ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 635.9ms
# Speed: 4.1ms preprocess, 635.9ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 622.3ms
# Speed: 8.2ms preprocess, 622.3ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 641.7ms
# Speed: 2.7ms preprocess, 641.7ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 635.7ms
# Speed: 8.3ms preprocess, 635.7ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 406.1ms
# Speed: 2.6ms preprocess, 406.1ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 390.5ms
# Speed: 4.3ms preprocess, 390.5ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
# Output video saved to output_yoga_pose.mp4

# %%
import shutil
import os

# Input video path
video_path = "/content/drive/MyDrive/Research/10 min Yoga for Beginners - Gentle & Simple Yoga Stretch.mp4"

# Output video originally saved here
output_video_path = "output_yoga_pose.mp4"   # current working directory

# Destination folder (same as input video)
dest_dir = os.path.dirname(video_path)
dest_path = os.path.join(dest_dir, "output_yoga_pose.mp4")

# Copy file
shutil.copy(output_video_path, dest_path)

print(f"Copied output video to: {dest_path}")
# Out:
# Copied output video to: /content/drive/MyDrive/Research/output_yoga_pose.mp4

# %%
import cv2
import os
from google.colab.patches import cv2_imshow

# Path to the output video
output_video_path = "/content/ultralytics/output_yoga_pose.mp4" # Update this if the path is different

# Create a directory to save screenshots
screenshot_dir = "screenshots"
os.makedirs(screenshot_dir, exist_ok=True)

cap = cv2.VideoCapture(output_video_path)

if not cap.isOpened():
    print("Error opening video file")
else:
    frame_count = 0
    screenshot_interval = 1000 # Save a screenshot every 100 frames
    while cap.isOpened():
        ret, frame = cap.read()
        if not ret:
            break

        # Display the frame (optional, can be slow for large videos)
        # cv2_imshow(frame)

        # Save screenshot at intervals
        if frame_count % screenshot_interval == 0:
            screenshot_path = os.path.join(screenshot_dir, f"frame_{frame_count:05d}.png")
            cv2.imwrite(screenshot_path, frame)
            print(f"Saved screenshot: {screenshot_path}")

        frame_count += 1

        # Press 'q' to exit the video display
        # if cv2.waitKey(1) & 0xFF == ord('q'):
        #     break

    cap.release()
    # cv2.destroyAllWindows() # Not needed with cv2_imshow

print("Video processing complete. Screenshots saved to:", screenshot_dir)
# Out:
# Saved screenshot: screenshots/frame_00000.png
# Saved screenshot: screenshots/frame_01000.png
# Saved screenshot: screenshots/frame_02000.png
# Saved screenshot: screenshots/frame_03000.png
# Saved screenshot: screenshots/frame_04000.png
# Saved screenshot: screenshots/frame_05000.png
# Saved screenshot: screenshots/frame_06000.png
# Saved screenshot: screenshots/frame_07000.png
# Saved screenshot: screenshots/frame_08000.png
# Saved screenshot: screenshots/frame_09000.png
# Saved screenshot: screenshots/frame_10000.png
# Saved screenshot: screenshots/frame_11000.png
# Saved screenshot: screenshots/frame_12000.png
# Saved screenshot: screenshots/frame_13000.png
# Saved screenshot: screenshots/frame_14000.png
# Saved screenshot: screenshots/frame_15000.png
# Saved screenshot: screenshots/frame_16000.png
# Saved screenshot: screenshots/frame_17000.png
# Saved screenshot: screenshots/frame_18000.png
# Saved screenshot: screenshots/frame_19000.png
# Video processing complete. Screenshots saved to: screenshots

# %%
import shutil
import os

# Input video path (used to determine the destination directory in Drive)
video_path = "/content/drive/MyDrive/Research/10 min Yoga for Beginners - Gentle & Simple Yoga Stretch.mp4"

# Source directory (where screenshots are saved)
screenshot_dir = "screenshots"

# Destination directory (same as the input video)
dest_dir = os.path.dirname(video_path)
dest_path = os.path.join(dest_dir, screenshot_dir)

# Copy the directory
shutil.copytree(screenshot_dir, dest_path)

print(f"Copied screenshots to: {dest_path}")
